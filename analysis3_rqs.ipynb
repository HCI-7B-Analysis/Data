# %% [markdown]
# # Analysis: Step 3 - Research Questions

# %%
import polars as pl

(
    pl
        .read_csv("./included.csv")
        .with_columns(Tags=pl.col("Tags").str.split("; "))
        .filter(pl.col("Tags").list.contains(pl.lit("RQ1")))
)
# Out:
# shape: (12, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Title     ┆ Authors   ┆ Abstract  ┆ Published ┆ … ┆ Covidence ┆ Study     ┆ Notes     ┆ Tags     │
# │ ---       ┆ ---       ┆ ---       ┆ Year      ┆   ┆ #         ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ str       ┆ str       ┆ list[str │
# │           ┆           ┆           ┆ i64       ┆   ┆ str       ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Teen      ┆ Alluhidan ┆ The       ┆ 2024      ┆ … ┆ #3        ┆ Alluhidan ┆ Hugo      ┆ ["HUGO", │
# │ Talk: The ┆ , Abdulma ┆ debate on ┆           ┆   ┆           ┆ 2024      ┆ Whittome  ┆ "Long",  │
# │ Good, the ┆ lik;      ┆ whether   ┆           ┆   ┆           ┆           ┆ (2026-04- ┆ "RQ1"]   │
# ...
